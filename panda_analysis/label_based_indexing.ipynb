# %%
import pandas as pd

# %%
dataset= pd.read_csv("Campus_Placement_Tracker_500.csv")

# %%
dataset
# Out:
#     Roll Number First Name Last Name  Gender      Branch    Company  \
# 0     22BCE6764     Shruti     Gupta  Female       Civil  Capgemini
# 1     22BCE1856        Dev    Sharma    Male  Mechanical  Cognizant
# 2     22BCE7769        Dev    Pandey    Male         ECE        TCS
# 3     22BCE3591     Atharv     Mehta  Female         ECE    Infosys
# 4     22BCE2533        Sai   Agarwal    Male       Civil        TCS
# ..          ...        ...       ...     ...         ...        ...
# 495   22BCE9836      Aarav     Verma    Male         EEE     Google
# 496   22BCE3684        Dev     Joshi  Female       Civil      Wipro
# 497   22BCE3357     Ishaan     Reddy  Female       Civil     Google
# 498   22BCE6715    Kritika    Kapoor    Male          IT        TCS
# 499   22BCE7062      Arjun    Kapoor    Male  Mechanical     Google
#
#      CTC (LPA)           Job Role
# 0         3.43  Software Engineer
# 1         5.63       Data Analyst
# 2         4.17  Software Engineer
# ...

# %%
dataset.loc[477,"Company"]
# Out:
# 'Wipro'

# %%
dataset.loc[[89,379],"Branch":]
# Out:
#          Branch  Company  CTC (LPA)        Job Role
# 89           IT  Infosys       3.33  System Analyst
# 379  Mechanical   Google       6.32    Data Analyst

# %%
dataset.loc[[289,467],:]
# Out:
#     Roll Number First Name Last Name  Gender Branch  Company  CTC (LPA)  \
# 289   22BCE1111      Naman      Nair  Female     IT  Infosys      26.69
# 467   22BCE3260       Sara      Nair    Male  Civil      TCS       6.00
#
#               Job Role
# 289  Backend Developer
# 467    DevOps Engineer

# %%
dataset.loc[300:400,:]
# Out:
#     Roll Number First Name Last Name  Gender      Branch    Company  \
# 300   22BCE8931      Kabir     Joshi  Female       Civil  Capgemini
# 301   22BCE7132       Myra       Das  Female         EEE      Wipro
# 302   22BCE7182     Ishaan     Joshi  Female  Mechanical     Amazon
# 303   22BCE6925      Meera    Pandey  Female         ECE     Google
# 304   22BCE1237       Myra    Sharma    Male         CSE     Amazon
# ..          ...        ...       ...     ...         ...        ...
# 396   22BCE8016       Yash     Ghosh    Male          IT  Microsoft
# 397   22BCE3080       Sara      Iyer    Male         ECE  Microsoft
# 398   22BCE5093      Tanvi     Yadav  Female         ECE    Infosys
# 399   22BCE4221    Krishna       Das  Female  Mechanical     Amazon
# 400   22BCE1650     Vihaan    Pandey  Female         EEE      Wipro
#
#      CTC (LPA)           Job Role
# 300      21.27  Software Engineer
# 301      17.25  Backend Developer
# 302       8.48  Software Engineer
# ...

# %%
dataset.loc[:369,"Branch"]
# Out:
# 0           Civil
# 1      Mechanical
# 2             ECE
# 3             ECE
# 4           Civil
#           ...
# 365           CSE
# 366           ECE
# 367           ECE
# 368         Civil
# 369         Civil
# Name: Branch, Length: 370, dtype: object
