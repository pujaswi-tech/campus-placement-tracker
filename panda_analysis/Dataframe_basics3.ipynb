# %% [markdown]
# # Using apply(),map(),applymap()

# %%
import pandas as pd

# %%
dataset= pd.read_csv("Campus_Placement_Tracker_500.csv")

# %%
dataset["Gender Short"] = dataset["Gender"].map({"Male": "M", "Female": "F"})

# %%
dataset
# Out:
#     Roll Number First Name Last Name  Gender      Branch    Company  \
# 0     22BCE6764     Shruti     Gupta  Female       Civil  Capgemini
# 1     22BCE1856        Dev    Sharma    Male  Mechanical  Cognizant
# 2     22BCE7769        Dev    Pandey    Male         ECE        TCS
# 3     22BCE3591     Atharv     Mehta  Female         ECE    Infosys
# 4     22BCE2533        Sai   Agarwal    Male       Civil        TCS
# ..          ...        ...       ...     ...         ...        ...
# 495   22BCE9836      Aarav     Verma    Male         EEE     Google
# 496   22BCE3684        Dev     Joshi  Female       Civil      Wipro
# 497   22BCE3357     Ishaan     Reddy  Female       Civil     Google
# 498   22BCE6715    Kritika    Kapoor    Male          IT        TCS
# 499   22BCE7062      Arjun    Kapoor    Male  Mechanical     Google
#
#      CTC (LPA)           Job Role Gender Short
# 0         3.43  Software Engineer            F
# 1         5.63       Data Analyst            M
# ...

# %%
def classify_ctc(ctc):
    if ctc > 20:
        return "Super Dream"
    elif ctc > 10:
        return "Dream"
    else:
        return "Non-Dream"

dataset["CTC Category"] = dataset["CTC (LPA)"].apply(classify_ctc)

# %%
dataset.head()
# Out:
#   Roll Number First Name Last Name  Gender      Branch    Company  CTC (LPA)  \
# 0   22BCE6764     Shruti     Gupta  Female       Civil  Capgemini       3.43
# 1   22BCE1856        Dev    Sharma    Male  Mechanical  Cognizant       5.63
# 2   22BCE7769        Dev    Pandey    Male         ECE        TCS       4.17
# 3   22BCE3591     Atharv     Mehta  Female         ECE    Infosys       3.42
# 4   22BCE2533        Sai   Agarwal    Male       Civil        TCS       3.14
#
#             Job Role Gender Short CTC Category
# 0  Software Engineer            F    Non-Dream
# 1       Data Analyst            M    Non-Dream
# 2  Software Engineer            M    Non-Dream
# 3    DevOps Engineer            F    Non-Dream
# 4    DevOps Engineer            M    Non-Dream

# %%
def full_name(row):
    return f"{row['First Name']} {row['Last Name']}"

dataset["Full Name"] = dataset.apply(full_name, axis=1)

# %%
dataset.head()
# Out:
#   Roll Number First Name Last Name  Gender      Branch    Company  CTC (LPA)  \
# 0   22BCE6764     Shruti     Gupta  Female       Civil  Capgemini       3.43
# 1   22BCE1856        Dev    Sharma    Male  Mechanical  Cognizant       5.63
# 2   22BCE7769        Dev    Pandey    Male         ECE        TCS       4.17
# 3   22BCE3591     Atharv     Mehta  Female         ECE    Infosys       3.42
# 4   22BCE2533        Sai   Agarwal    Male       Civil        TCS       3.14
#
#             Job Role Gender Short CTC Category     Full Name
# 0  Software Engineer            F    Non-Dream  Shruti Gupta
# 1       Data Analyst            M    Non-Dream    Dev Sharma
# 2  Software Engineer            M    Non-Dream    Dev Pandey
# 3    DevOps Engineer            F    Non-Dream  Atharv Mehta
# 4    DevOps Engineer            M    Non-Dream   Sai Agarwal

# %%
dataset["First Name"] = dataset["First Name"].map(str.upper)
dataset["Last Name"] = dataset["Last Name"].map(str.upper)

# %%
dataset.head(5)
# Out:
#   Roll Number First Name Last Name  Gender      Branch    Company  CTC (LPA)  \
# 0   22BCE6764     SHRUTI     GUPTA  Female       Civil  Capgemini       3.43
# 1   22BCE1856        DEV    SHARMA    Male  Mechanical  Cognizant       5.63
# 2   22BCE7769        DEV    PANDEY    Male         ECE        TCS       4.17
# 3   22BCE3591     ATHARV     MEHTA  Female         ECE    Infosys       3.42
# 4   22BCE2533        SAI   AGARWAL    Male       Civil        TCS       3.14
#
#             Job Role Gender Short CTC Category     Full Name
# 0  Software Engineer            F    Non-Dream  Shruti Gupta
# 1       Data Analyst            M    Non-Dream    Dev Sharma
# 2  Software Engineer            M    Non-Dream    Dev Pandey
# 3    DevOps Engineer            F    Non-Dream  Atharv Mehta
# 4    DevOps Engineer            M    Non-Dream   Sai Agarwal
