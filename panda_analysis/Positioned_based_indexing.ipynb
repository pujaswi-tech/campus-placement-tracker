# %%
import pandas as pd

# %%
dataset= pd.read_csv("Campus_Placement_Tracker_500.csv",index_col="First Name")

# %%
dataset
# Out:
#            Roll Number Last Name  Gender      Branch    Company  CTC (LPA)  \
# First Name
# Shruti       22BCE6764     Gupta  Female       Civil  Capgemini       3.43
# Dev          22BCE1856    Sharma    Male  Mechanical  Cognizant       5.63
# Dev          22BCE7769    Pandey    Male         ECE        TCS       4.17
# Atharv       22BCE3591     Mehta  Female         ECE    Infosys       3.42
# Sai          22BCE2533   Agarwal    Male       Civil        TCS       3.14
# ...                ...       ...     ...         ...        ...        ...
# Aarav        22BCE9836     Verma    Male         EEE     Google      21.62
# Dev          22BCE3684     Joshi  Female       Civil      Wipro      13.19
# Ishaan       22BCE3357     Reddy  Female       Civil     Google      12.04
# Kritika      22BCE6715    Kapoor    Male          IT        TCS      20.80
# Arjun        22BCE7062    Kapoor    Male  Mechanical     Google      22.68
#
#                      Job Role
# First Name
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Roll Number  500 non-null    object
#  1   First Name   500 non-null    object
#  2   Last Name    500 non-null    object
#  3   Gender       500 non-null    object
#  4   Branch       500 non-null    object
#  5   Company      500 non-null    object
#  6   CTC (LPA)    500 non-null    float64
#  7   Job Role     500 non-null    object
# dtypes: float64(1), object(7)
# memory usage: 31.4+ KB

# %% [markdown]
# # Selecting rows with iloc[]

# %%
dataset.iloc[0]
# Out:
# Roll Number            22BCE6764
# Last Name                  Gupta
# Gender                    Female
# Branch                     Civil
# Company                Capgemini
# CTC (LPA)                   3.43
# Job Role       Software Engineer
# Name: Shruti, dtype: object

# %%
type(dataset.iloc[0])
# Out:
# pandas.core.series.Series

# %%
dataset.iloc[1]
# Out:
# Roll Number       22BCE1856
# Last Name            Sharma
# Gender                 Male
# Branch           Mechanical
# Company           Cognizant
# CTC (LPA)              5.63
# Job Role       Data Analyst
# Name: Dev, dtype: object

# %%
dataset.iloc[-1]
# Out:
# Roll Number         22BCE7062
# Last Name              Kapoor
# Gender                   Male
# Branch             Mechanical
# Company                Google
# CTC (LPA)               22.68
# Job Role       System Analyst
# Name: Arjun, dtype: object

# %%
dataset.iloc[[1,2,3]]
# Out:
#            Roll Number Last Name  Gender      Branch    Company  CTC (LPA)  \
# First Name
# Dev          22BCE1856    Sharma    Male  Mechanical  Cognizant       5.63
# Dev          22BCE7769    Pandey    Male         ECE        TCS       4.17
# Atharv       22BCE3591     Mehta  Female         ECE    Infosys       3.42
#
#                      Job Role
# First Name
# Dev              Data Analyst
# Dev         Software Engineer
# Atharv        DevOps Engineer

# %%
dataset.iloc[1:5]
# Out:
#            Roll Number Last Name  Gender      Branch    Company  CTC (LPA)  \
# First Name
# Dev          22BCE1856    Sharma    Male  Mechanical  Cognizant       5.63
# Dev          22BCE7769    Pandey    Male         ECE        TCS       4.17
# Atharv       22BCE3591     Mehta  Female         ECE    Infosys       3.42
# Sai          22BCE2533   Agarwal    Male       Civil        TCS       3.14
#
#                      Job Role
# First Name
# Dev              Data Analyst
# Dev         Software Engineer
# Atharv        DevOps Engineer
# Sai           DevOps Engineer

# %%
dataset.iloc[0,[0,1,2]]
# Out:
# Roll Number    22BCE6764
# Last Name          Gupta
# Gender            Female
# Name: Shruti, dtype: object

# %%
dataset.iloc[23:33,[1,2]]
# Out:
#            Last Name  Gender
# First Name
# Yash           Mehta    Male
# Prisha        Mishra    Male
# Sai           Pandey    Male
# Sara          Pandey  Female
# Pihu           Verma    Male
# Aadhya        Chopra    Male
# Kunal            Das    Male
# Shruti        Kapoor    Male
# Kunal         Sharma  Female
# Avni           Ghosh    Male

# %% [markdown]
# # Selecting columns with iloc[]

# %%
dataset.iloc[:,4]
# Out:
# First Name
# Shruti     Capgemini
# Dev        Cognizant
# Dev              TCS
# Atharv       Infosys
# Sai              TCS
#              ...
# Aarav         Google
# Dev            Wipro
# Ishaan        Google
# Kritika          TCS
# Arjun         Google
# Name: Company, Length: 500, dtype: object

# %%
dataset.iloc[:,:]
# Out:
#            Roll Number Last Name  Gender      Branch    Company  CTC (LPA)  \
# First Name
# Shruti       22BCE6764     Gupta  Female       Civil  Capgemini       3.43
# Dev          22BCE1856    Sharma    Male  Mechanical  Cognizant       5.63
# Dev          22BCE7769    Pandey    Male         ECE        TCS       4.17
# Atharv       22BCE3591     Mehta  Female         ECE    Infosys       3.42
# Sai          22BCE2533   Agarwal    Male       Civil        TCS       3.14
# ...                ...       ...     ...         ...        ...        ...
# Aarav        22BCE9836     Verma    Male         EEE     Google      21.62
# Dev          22BCE3684     Joshi  Female       Civil      Wipro      13.19
# Ishaan       22BCE3357     Reddy  Female       Civil     Google      12.04
# Kritika      22BCE6715    Kapoor    Male          IT        TCS      20.80
# Arjun        22BCE7062    Kapoor    Male  Mechanical     Google      22.68
#
#                      Job Role
# First Name
# ...

# %%
dataset["Job Role"]
# Out:
# First Name
# Shruti     Software Engineer
# Dev             Data Analyst
# Dev        Software Engineer
# Atharv       DevOps Engineer
# Sai          DevOps Engineer
#                  ...
# Aarav      Backend Developer
# Dev             Data Analyst
# Ishaan       DevOps Engineer
# Kritika       System Analyst
# Arjun         System Analyst
# Name: Job Role, Length: 500, dtype: object
