# %% [markdown]
# # Filtering DataFrames with one Condition

# %%
import pandas as pd

# %%
dataset= pd.read_csv("Campus_Placement_Tracker_500.csv")

# %%
dataset.head(10)
# Out:
#   Roll Number First Name Last Name  Gender      Branch    Company  CTC (LPA)  \
# 0   22BCE6764     Shruti     Gupta  Female       Civil  Capgemini       3.43
# 1   22BCE1856        Dev    Sharma    Male  Mechanical  Cognizant       5.63
# 2   22BCE7769        Dev    Pandey    Male         ECE        TCS       4.17
# 3   22BCE3591     Atharv     Mehta  Female         ECE    Infosys       3.42
# 4   22BCE2533        Sai   Agarwal    Male       Civil        TCS       3.14
# 5   22BCE5451     Saanvi    Pandey  Female         CSE     Amazon       5.92
# 6   22BCE2600      Aryan     Reddy  Female          IT  Cognizant       4.41
# 7   22BCE3414      Harsh     Singh  Female  Mechanical    Infosys       4.71
# 8   22BCE9616     Ananya    Kapoor    Male  Mechanical  Microsoft       4.93
# 9   22BCE4193      Kiara     Kumar    Male       Civil    Infosys       5.31
#
#             Job Role
# 0  Software Engineer
# 1       Data Analyst
# 2  Software Engineer
# 3    DevOps Engineer
# ...

# %%
dataset.Gender.head(10)
# Out:
# 0    Female
# 1      Male
# 2      Male
# 3    Female
# 4      Male
# 5    Female
# 6    Female
# 7    Female
# 8      Male
# 9      Male
# Name: Gender, dtype: object

# %%
dataset.Gender == "Male"
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 495     True
# 496    False
# 497    False
# 498     True
# 499     True
# Name: Gender, Length: 500, dtype: bool

# %%
dataset[dataset.Gender == "Male"]
# Out:
#     Roll Number First Name Last Name Gender      Branch    Company  CTC (LPA)  \
# 1     22BCE1856        Dev    Sharma   Male  Mechanical  Cognizant       5.63
# 2     22BCE7769        Dev    Pandey   Male         ECE        TCS       4.17
# 4     22BCE2533        Sai   Agarwal   Male       Civil        TCS       3.14
# 8     22BCE9616     Ananya    Kapoor   Male  Mechanical  Microsoft       4.93
# 9     22BCE4193      Kiara     Kumar   Male       Civil    Infosys       5.31
# ..          ...        ...       ...    ...         ...        ...        ...
# 492   22BCE8218        Dev      Nair   Male          IT      Wipro       8.13
# 493   22BCE7871    Krishna       Das   Male  Mechanical  Cognizant      21.34
# 495   22BCE9836      Aarav     Verma   Male         EEE     Google      21.62
# 498   22BCE6715    Kritika    Kapoor   Male          IT        TCS      20.80
# 499   22BCE7062      Arjun    Kapoor   Male  Mechanical     Google      22.68
#
#               Job Role
# ...

# %%
dataset[dataset.Gender == "Male"]["CTC (LPA)"]
# Out:
# 1       5.63
# 2       4.17
# 4       3.14
# 8       4.93
# 9       5.31
#        ...
# 492     8.13
# 493    21.34
# 495    21.62
# 498    20.80
# 499    22.68
# Name: CTC (LPA), Length: 244, dtype: float64

# %%
mask1 = dataset.Gender == "Male"
mask1
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 495     True
# 496    False
# 497    False
# 498     True
# 499     True
# Name: Gender, Length: 500, dtype: bool

# %%
dataset_male = dataset.loc[mask1]

# %%
dataset_male.head()
# Out:
#   Roll Number First Name Last Name Gender      Branch    Company  CTC (LPA)  \
# 1   22BCE1856        Dev    Sharma   Male  Mechanical  Cognizant       5.63
# 2   22BCE7769        Dev    Pandey   Male         ECE        TCS       4.17
# 4   22BCE2533        Sai   Agarwal   Male       Civil        TCS       3.14
# 8   22BCE9616     Ananya    Kapoor   Male  Mechanical  Microsoft       4.93
# 9   22BCE4193      Kiara     Kumar   Male       Civil    Infosys       5.31
#
#             Job Role
# 1       Data Analyst
# 2  Software Engineer
# 4    DevOps Engineer
# 8  Software Engineer
# 9  Software Engineer

# %%
dataset.dtypes == object
# Out:
# Roll Number     True
# First Name      True
# Last Name       True
# Gender          True
# Branch          True
# Company         True
# CTC (LPA)      False
# Job Role        True
# dtype: bool

# %%
dataset.dtypes# == object
# Out:
# Roll Number     object
# First Name      object
# Last Name       object
# Gender          object
# Branch          object
# Company         object
# CTC (LPA)      float64
# Job Role        object
# dtype: object

# %%
mask2 = dataset.dtypes == object
mask2
# Out:
# Roll Number     True
# First Name      True
# Last Name       True
# Gender          True
# Branch          True
# Company         True
# CTC (LPA)      False
# Job Role        True
# dtype: bool

# %%
dataset.loc[:,mask2]
# Out:
#     Roll Number First Name Last Name  Gender      Branch    Company  \
# 0     22BCE6764     Shruti     Gupta  Female       Civil  Capgemini
# 1     22BCE1856        Dev    Sharma    Male  Mechanical  Cognizant
# 2     22BCE7769        Dev    Pandey    Male         ECE        TCS
# 3     22BCE3591     Atharv     Mehta  Female         ECE    Infosys
# 4     22BCE2533        Sai   Agarwal    Male       Civil        TCS
# ..          ...        ...       ...     ...         ...        ...
# 495   22BCE9836      Aarav     Verma    Male         EEE     Google
# 496   22BCE3684        Dev     Joshi  Female       Civil      Wipro
# 497   22BCE3357     Ishaan     Reddy  Female       Civil     Google
# 498   22BCE6715    Kritika    Kapoor    Male          IT        TCS
# 499   22BCE7062      Arjun    Kapoor    Male  Mechanical     Google
#
#               Job Role
# 0    Software Engineer
# 1         Data Analyst
# 2    Software Engineer
# 3      DevOps Engineer
# 4      DevOps Engineer
# ...

# %%
dataset.loc[:,~mask2]
# Out:
#      CTC (LPA)
# 0         3.43
# 1         5.63
# 2         4.17
# 3         3.42
# 4         3.14
# ..         ...
# 495      21.62
# 496      13.19
# 497      12.04
# 498      20.80
# 499      22.68
#
# [500 rows x 1 columns]

# %%
dataset.loc[mask1,~mask2]
# Out:
#      CTC (LPA)
# 1         5.63
# 2         4.17
# 4         3.14
# 8         4.93
# 9         5.31
# ..         ...
# 492       8.13
# 493      21.34
# 495      21.62
# 498      20.80
# 499      22.68
#
# [244 rows x 1 columns]
