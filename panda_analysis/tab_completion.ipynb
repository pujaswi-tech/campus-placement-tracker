# %%
import pandas as pd

# %%
dataframe = pd.read_csv("Campus_Placement_Tracker_500.csv")

# %%
dataframe.sort_values
# Out:
# <bound method DataFrame.sort_values of     Roll Number First Name Last Name  Gender      Branch    Company  \
# 0     22BCE6764     Shruti     Gupta  Female       Civil  Capgemini
# 1     22BCE1856        Dev    Sharma    Male  Mechanical  Cognizant
# 2     22BCE7769        Dev    Pandey    Male         ECE        TCS
# 3     22BCE3591     Atharv     Mehta  Female         ECE    Infosys
# 4     22BCE2533        Sai   Agarwal    Male       Civil        TCS
# ..          ...        ...       ...     ...         ...        ...
# 495   22BCE9836      Aarav     Verma    Male         EEE     Google
# 496   22BCE3684        Dev     Joshi  Female       Civil      Wipro
# 497   22BCE3357     Ishaan     Reddy  Female       Civil     Google
# 498   22BCE6715    Kritika    Kapoor    Male          IT        TCS
# 499   22BCE7062      Arjun    Kapoor    Male  Mechanical     Google
#
#      CTC (LPA)           Job Role
# 0         3.43  Software Engineer
# 1         5.63       Data Analyst
# ...

# %%
dataframe.sort_values("CTC (LPA)")
# Out:
#     Roll Number First Name Last Name  Gender      Branch    Company  \
# 17    22BCE7696      Aryan   Agarwal  Female  Mechanical  Cognizant
# 114   22BCE8597      Naman     Sinha    Male         EEE    Infosys
# 44    22BCE7173      Kiara   Agarwal  Female         CSE     Amazon
# 184   22BCE4403      Kunal     Joshi  Female          IT  Capgemini
# 130   22BCE9230     Saanvi       Das    Male         CSE    Infosys
# ..          ...        ...       ...     ...         ...        ...
# 415   22BCE7064      Meera    Mishra    Male         EEE        TCS
# 404   22BCE3028    Kritika     Verma  Female  Mechanical  Microsoft
# 275   22BCE7170    Kritika    Chopra    Male       Civil        TCS
# 325   22BCE8383      Meera    Chopra  Female         ECE     Google
# 321   22BCE3820     Shruti       Das    Male         ECE     Amazon
#
#      CTC (LPA)           Job Role
# 17        3.00  Backend Developer
# 114       3.01  Software Engineer
# 44        3.03    DevOps Engineer
# ...

# %%
dataframe.sort_values(by = "CTC (LPA)",ascending= False)
# Out:
#     Roll Number First Name Last Name  Gender      Branch    Company  \
# 321   22BCE3820     Shruti       Das    Male         ECE     Amazon
# 325   22BCE8383      Meera    Chopra  Female         ECE     Google
# 275   22BCE7170    Kritika    Chopra    Male       Civil        TCS
# 404   22BCE3028    Kritika     Verma  Female  Mechanical  Microsoft
# 415   22BCE7064      Meera    Mishra    Male         EEE        TCS
# ..          ...        ...       ...     ...         ...        ...
# 130   22BCE9230     Saanvi       Das    Male         CSE    Infosys
# 184   22BCE4403      Kunal     Joshi  Female          IT  Capgemini
# 44    22BCE7173      Kiara   Agarwal  Female         CSE     Amazon
# 114   22BCE8597      Naman     Sinha    Male         EEE    Infosys
# 17    22BCE7696      Aryan   Agarwal  Female  Mechanical  Cognizant
#
#      CTC (LPA)           Job Role
# 321      29.92     System Analyst
# 325      29.91      Web Developer
# 275      29.67    DevOps Engineer
# ...
