# %% [markdown]
# # Splitting with many Keys

# %%
import pandas as pd

# %%
dataset= pd.read_csv("Campus_Placement_Tracker_500.csv")

# %%
dataset.head()
# Out:
#   Roll Number First Name Last Name  Gender      Branch    Company  CTC (LPA)  \
# 0   22BCE6764     Shruti     Gupta  Female       Civil  Capgemini       3.43
# 1   22BCE1856        Dev    Sharma    Male  Mechanical  Cognizant       5.63
# 2   22BCE7769        Dev    Pandey    Male         ECE        TCS       4.17
# 3   22BCE3591     Atharv     Mehta  Female         ECE    Infosys       3.42
# 4   22BCE2533        Sai   Agarwal    Male       Civil        TCS       3.14
#
#             Job Role
# 0  Software Engineer
# 1       Data Analyst
# 2  Software Engineer
# 3    DevOps Engineer
# 4    DevOps Engineer

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Roll Number  500 non-null    object
#  1   First Name   500 non-null    object
#  2   Last Name    500 non-null    object
#  3   Gender       500 non-null    object
#  4   Branch       500 non-null    object
#  5   Company      500 non-null    object
#  6   CTC (LPA)    500 non-null    float64
#  7   Job Role     500 non-null    object
# dtypes: float64(1), object(7)
# memory usage: 31.4+ KB

# %%
dataset.Branch.nunique()
# Out:
# 6

# %%
split1=dataset.groupby("Branch")

# %%
l= list(split1)
l
# Out:
# [('CSE',
#       Roll Number First Name Last Name  Gender Branch    Company  CTC (LPA)  \
#   5     22BCE5451     Saanvi    Pandey  Female    CSE     Amazon       5.92
#   13    22BCE8918     Shruti      Iyer    Male    CSE    Infosys       4.90
#   14    22BCE3599       Avni     Yadav  Female    CSE    Infosys       5.73
#   18    22BCE6285      Kunal     Patel    Male    CSE  Microsoft       5.32
#   22    22BCE4245       Avni       Das  Female    CSE     Amazon       4.72
#   ..          ...        ...       ...     ...    ...        ...        ...
#   473   22BCE6558      Meera     Ghosh    Male    CSE        TCS      11.53
#   477   22BCE4231       Avni     Ghosh  Female    CSE      Wipro      24.08
#   478   22BCE8618      Arjun     Ghosh  Female    CSE  Cognizant      26.30
#   483   22BCE7695      Meera     Kumar  Female    CSE    Infosys      27.14
#   485   22BCE2789      Kiara      Iyer  Female    CSE  Cognizant      12.07
#
#                 Job Role
# ...

# %%
len(l)
# Out:
# 6

# %%
l[5][1]
# Out:
#     Roll Number First Name Last Name  Gender      Branch    Company  \
# 1     22BCE1856        Dev    Sharma    Male  Mechanical  Cognizant
# 7     22BCE3414      Harsh     Singh  Female  Mechanical    Infosys
# 8     22BCE9616     Ananya    Kapoor    Male  Mechanical  Microsoft
# 10    22BCE1711     Vihaan    Chopra    Male  Mechanical    Infosys
# 17    22BCE7696      Aryan   Agarwal  Female  Mechanical  Cognizant
# ..          ...        ...       ...     ...         ...        ...
# 443   22BCE6196        Dev    Sharma  Female  Mechanical  Capgemini
# 472   22BCE5484     Atharv     Verma  Female  Mechanical      Wipro
# 474   22BCE1282        Ira     Ghosh    Male  Mechanical  Cognizant
# 493   22BCE7871    Krishna       Das    Male  Mechanical  Cognizant
# 499   22BCE7062      Arjun    Kapoor    Male  Mechanical     Google
#
#      CTC (LPA)           Job Role
# 1         5.63       Data Analyst
# 7         4.71    DevOps Engineer
# 8         4.93  Software Engineer
# ...

# %%
split2 = dataset.groupby(by=["Branch","Gender"])

# %%
l2=list(split2)
l2
# Out:
# [(('CSE', 'Female'),
#       Roll Number First Name Last Name  Gender Branch    Company  CTC (LPA)  \
#   5     22BCE5451     Saanvi    Pandey  Female    CSE     Amazon       5.92
#   14    22BCE3599       Avni     Yadav  Female    CSE    Infosys       5.73
#   22    22BCE4245       Avni       Das  Female    CSE     Amazon       4.72
#   44    22BCE7173      Kiara   Agarwal  Female    CSE     Amazon       3.03
#   50    22BCE2251      Tanya     Singh  Female    CSE  Microsoft       4.43
#   53    22BCE8089     Ananya    Sharma  Female    CSE  Cognizant       4.45
#   59    22BCE7198      Arjun     Joshi  Female    CSE  Microsoft       4.40
#   74    22BCE2995     Aditya     Sinha  Female    CSE     Google       4.80
#   81    22BCE3668       Pihu     Kumar  Female    CSE      Wipro       5.01
#   95    22BCE1102     Ananya      Iyer  Female    CSE        TCS       5.82
#   112   22BCE3477     Ishaan    Mishra  Female    CSE  Microsoft       3.40
# ...

# %%
len(l2)
# Out:
# 12

# %%
l2[4]
# Out:
# (('ECE', 'Female'),
#      Roll Number First Name Last Name  Gender Branch    Company  CTC (LPA)  \
#  3     22BCE3591     Atharv     Mehta  Female    ECE    Infosys       3.42
#  40    22BCE2161      Kabir    Pandey  Female    ECE     Amazon       3.65
#  45    22BCE2435     Saanvi     Gupta  Female    ECE    Infosys       3.48
#  51    22BCE2083      Anika     Patel  Female    ECE     Amazon       5.87
#  73    22BCE1906       Avni    Pandey  Female    ECE  Cognizant       5.22
#  85    22BCE1212     Shruti    Mishra  Female    ECE  Microsoft       4.35
#  97    22BCE5784     Vihaan     Sinha  Female    ECE        TCS       4.95
#  151   22BCE5432    Krishna     Reddy  Female    ECE     Google       4.66
#  157   22BCE8957      Kabir     Singh  Female    ECE  Capgemini       4.95
#  171   22BCE7552   Niharika    Kapoor  Female    ECE  Cognizant       3.98
#  182   22BCE9161     Trisha     Joshi  Female    ECE  Capgemini       3.66
# ...

# %%
l2[4][0]
# Out:
# ('ECE', 'Female')

# %%
l2[4][1]
# Out:
#     Roll Number First Name Last Name  Gender Branch    Company  CTC (LPA)  \
# 3     22BCE3591     Atharv     Mehta  Female    ECE    Infosys       3.42
# 40    22BCE2161      Kabir    Pandey  Female    ECE     Amazon       3.65
# 45    22BCE2435     Saanvi     Gupta  Female    ECE    Infosys       3.48
# 51    22BCE2083      Anika     Patel  Female    ECE     Amazon       5.87
# 73    22BCE1906       Avni    Pandey  Female    ECE  Cognizant       5.22
# 85    22BCE1212     Shruti    Mishra  Female    ECE  Microsoft       4.35
# 97    22BCE5784     Vihaan     Sinha  Female    ECE        TCS       4.95
# 151   22BCE5432    Krishna     Reddy  Female    ECE     Google       4.66
# 157   22BCE8957      Kabir     Singh  Female    ECE  Capgemini       4.95
# 171   22BCE7552   Niharika    Kapoor  Female    ECE  Cognizant       3.98
# 182   22BCE9161     Trisha     Joshi  Female    ECE  Capgemini       3.66
# 222   22BCE1806      Anika      Iyer  Female    ECE      Wipro       5.84
# ...

# %%
l2[4][2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 l2[4][2]
#
# IndexError: tuple index out of range
